# %%
import Pkg;
Pkg.activate(@__DIR__);
Pkg.instantiate();
using PyPlot
# Out:
#   Activating environment at `~/SSD/Code/Julia/tinympc-dev-julia/rocket_landing_Zac/Project.toml`

# %%
hrz = [2, 4, 8, 16, 32, 64, 128, 256]
x = [1, 2, 3, 4, 5, 6, 7, 8]

tinympc_file = [38.1, 38.3, 42.4, 46.5, 46.7, 42.6, 42.4, 42.4]
ecos_file = [131.6, 135.8, 144.2, 169.1, 206.7, 286]
scs_file = [116.3, 119.8, 126.7, 140.2, 167.5, 226]

tinympc_ws = [0, 0, 0, 0, 0, 0, 0, 0]
ecos_ws = [21.6, 47.6, 99.7, 206.7, 416.6, 843.4]
scs_ws = [22.5, 49.1, 102.5, 209.3, 422.8, 849.8]
# Out:
# 6-element Vector{Float64}:
#   22.5
#   49.1
#  102.5
#  209.3
#  422.8
#  849.8

# %%
# fig1, ax1 = plt.subplots()
# # ax = fig.gca()
# plt.scatter(x, tinympc_file, label="TinyMPC", color="blue")
# plt.scatter(x[1:length(ecos_file)], ecos_file+ecos_ws, label="ECOS", color="red", marker="p")
# plt.scatter(x[1:length(scs_file)], scs_file+scs_ws, label="SCS", color="green", marker="s")
# plt.hlines(512, 1, 8, color="black")
# plt.xlabel("Horizon")
# plt.legend()
# ax1.xaxis.set_ticks(x) #set the ticks to be a
# ax1.xaxis.set_ticklabels(hrz) # change the ticks' names to x
# fig1

# %% [markdown]
# # MEMORY

# %%
fig1, ax1 = plt.subplots()
# ax = fig.gca()
plt.scatter(x, tinympc_file*0, label="TinyMPC", color="blue")
plt.scatter(x[1:length(ecos_file)], ecos_ws, label="ECOS", color="red", marker="p")
plt.scatter(x[1:length(scs_file)], scs_ws, label="SCS", color="green", marker="s")
plt.hlines(512, 1, 8, color="black")
plt.xlabel("Horizon")
plt.legend()
ax1.xaxis.set_ticks(x) #set the ticks to be a
ax1.xaxis.set_ticklabels(hrz) # change the ticks' names to x
fig1
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
